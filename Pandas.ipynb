# %%
import pandas as pd

# %%
data={"name":["A","B","C"],"age":[20,18,22],"marks":[75,82,68]}

# %%
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#   name  age  marks
# 0    A   20     75
# 1    B   18     82
# 2    C   22     68

# %%
df["marks"]
# Out:
# 0    75
# 1    82
# 2    68
# Name: marks, dtype: int64

# %%
df["marks"]+5
# Out:
# 0    80
# 1    87
# 2    73
# Name: marks, dtype: int64

# %%
s=pd.Series([10,20,30,40], index=['a','b','c','d'])

# %%
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
df.head()
# Out:
#   name  age  marks
# 0    A   20     75
# 1    B   18     82
# 2    C   22     68

# %%
df.shape
# Out:
# (3, 3)

# %%
df = pd.read_csv("/Data - Sheet1.csv")

# %%
df.head()
# Out:
#    SNo Roll Number Name Branch  Hobby-1    Hobby-2    Place  Marks  Age
# 0    1         5v5   h1    cse   vibing   swimming      hyd     98   18
# 1    2         5v6   h2    ece  classes  listening    vizag     90   23
# 2    3         5v7   h3     am    dance      music      blr     67   19
# 3    4         5v8   h4     gk    sleep     movies  chennai     54   20
# 4    5         5v9   h5   itws   vibing   swimming      hyd     45   21

# %%
df.info
# Out:
# <bound method DataFrame.info of     SNo Roll Number Name Branch  Hobby-1    Hobby-2    Place  Marks  Age
# 0     1         5v5   h1    cse   vibing   swimming      hyd     98   18
# 1     2         5v6   h2    ece  classes  listening    vizag     90   23
# 2     3         5v7   h3     am    dance      music      blr     67   19
# 3     4         5v8   h4     gk    sleep     movies  chennai     54   20
# 4     5         5v9   h5   itws   vibing   swimming      hyd     45   21
# 5     6        5v10   h6    eee  classes  listening    vizag     56   22
# 6     7        5v11   h7    dms    dance      music      blr     78   23
# 7     8        5v12   h8   dbms    sleep     movies  chennai     89   24
# 8     9        5v13   h9    aep   vibing   swimming      hyd     45   25
# 9    10        5v14  h10    bee  classes  listening    vizag     20   26
# 10   11        5v15  h11    cse    dance      music      blr     45   27
# ...

# %%
df["Marks"].median()
# Out:
# 55.0

# %%
df["Marks"].mode()
# Out:
# 0    45
# 1    98
# Name: Marks, dtype: int64

# %%
df["Marks"].max()
df["Marks"].quantile(0.25)
df["Marks"].quantile(0.50)
df["Marks"].quantile(0.75)
# Out:
# np.float64(80.75)

# %%
df["Marks"].std()
# Out:
# 25.23755555766675

# %%
df["Marks"].min()
# Out:
# 20

# %%
df["Marks"].mean()
# Out:
# np.float64(59.25)
